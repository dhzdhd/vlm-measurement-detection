# %%
import os
import keras
import keras_nlp
import numpy as np
import PIL
import requests
from PIL import Image
import numpy as np
import cv2
from PIL import Image, ImageFilter
import requests
import pandas as pd

# %%
os.environ["KERAS_BACKEND"] = "jax"
keras.config.set_floatx("bfloat16")

# %%
paligemma = keras_nlp.models.PaliGemmaCausalLM.from_preset("pali_gemma_3b_mix_224")
paligemma.summary()
# Out:
# Preprocessor: "pali_gemma_causal_lm_preprocessor_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Tokenizer (type)                                   ┃                                             Vocab # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ pali_gemma_tokenizer (PaliGemmaTokenizer)          │                                             257,152 │
# └────────────────────────────────────────────────────┴─────────────────────────────────────────────────────┘
# Model: "pali_gemma_causal_lm_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ images (InputLayer)           │ (None, 224, 224, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ padding_mask (InputLayer)     │ (None, None)              │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ response_mask (InputLayer)    │ (None, None)              │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ token_ids (InputLayer)        │ (None, None)              │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ pali_gemma_backbone           │ (None, None, 2048)        │   2,923,335,408 │ images[0][0],              │
# │ (PaliGemmaBackbone)           │                           │                 │ padding_mask[0][0],        │
# │                               │                           │                 │ response_mask[0][0],       │
# │                               │                           │                 │ token_ids[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ token_embedding               │ (None, None, 257152)      │     526,647,296 │ pali_gemma_backbone[0][0]  │
# │ (ReversibleEmbedding)         │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ get_item_1 (GetItem)          │ (None, None, 257152)      │               0 │ token_embedding[1][0]      │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 2,923,335,408 (5.45 GB)
#  Trainable params: 2,923,335,408 (5.45 GB)
#  Non-trainable params: 0 (0.00 B)

# %%
def sharpen_image(image):
    kernel = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]])
    sharpened = cv2.filter2D(np.array(image), -1, kernel)
    return Image.fromarray(sharpened)

# %%
def crop_and_resize(image, target_size):
    return image.resize(target_size, PIL.Image.Resampling.LANCZOS)

def read_image(url, target_size):
    image = PIL.Image.open(requests.get(url, stream=True).raw).convert('RGB')
    image = crop_and_resize(image, target_size)
    image = np.array(image)
    return image

# %%
target_size = (224, 224)
image_url = 'https://m.media-amazon.com/images/I/81N73b5khVL.jpg'
item_image = read_image(image_url, target_size)

# %%
test_df = pd.read_csv("/kaggle/input/amazonml/test.csv")
sample = test_df
result = pd.DataFrame({"index": [], "prediction": []})

# %%
for (idx, (index, url, id, ent_type)) in enumerate(sample.values):
    print(f"{idx}: {url}")
    item_image = read_image(url, target_size)

    if ent_type == "item_weight" or ent_type == "maximum_weight_recommendation":
        ent_type = "net weight"

    prompt = f'What is the item {ent_type}? Mention the unit too\n'
    output = paligemma.generate(
        inputs={
            "images": item_image,
            "prompts": prompt,
        }
    )
    print(output)
    result = pd.concat([result, pd.DataFrame({"index": [idx], "prediction": [output.split("\n")[1]]})], ignore_index=True)

    if idx == 5000:
        break
# Out:
# 0: https://m.media-amazon.com/images/I/110EibNyclL.jpg
# What is the item height? Mention the unit too
# 100cm - 103.5cm
# 1: https://m.media-amazon.com/images/I/11TU2clswzL.jpg
# What is the item width? Mention the unit too
# 158
# 2: https://m.media-amazon.com/images/I/11TU2clswzL.jpg
# What is the item height? Mention the unit too
# 16cm
# 3: https://m.media-amazon.com/images/I/11TU2clswzL.jpg
# What is the item depth? Mention the unit too
# 158
# 4: https://m.media-amazon.com/images/I/11gHj8dhhrL.jpg
# What is the item depth? Mention the unit too
# 16
# 5: https://m.media-amazon.com/images/I/11gHj8dhhrL.jpg
# What is the item height? Mention the unit too
# 110cm/43.3"
# 6: https://m.media-amazon.com/images/I/11gHj8dhhrL.jpg
# What is the item width? Mention the unit too
# 10cm/3.93"
# 7: https://m.media-amazon.com/images/I/11lshEUmCrL.jpg
# What is the item height? Mention the unit too
# 1.4 in 3.5 cm
# 8: https://m.media-amazon.com/images/I/21+i52HRW4L.jpg
# What is the item width? Mention the unit too
# 30 cm
# 9: https://m.media-amazon.com/images/I/21-LmSmehZL.jpg
# What is the item height? Mention the unit too
# 15 cm
# 10: https://m.media-amazon.com/images/I/213oP6n7jtL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 11: https://m.media-amazon.com/images/I/213wY3gUsmL.jpg
# What is the item width? Mention the unit too
# 139.5
# 12: https://m.media-amazon.com/images/I/214CLs1oznL.jpg
# What is the item depth? Mention the unit too
# 4.1 in
# 13: https://m.media-amazon.com/images/I/214CLs1oznL.jpg
# What is the item height? Mention the unit too
# 4.1 in 10 cm
# 14: https://m.media-amazon.com/images/I/214CLs1oznL.jpg
# What is the item width? Mention the unit too
# 4.1 in
# 15: https://m.media-amazon.com/images/I/216rjgJHAeL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 16: https://m.media-amazon.com/images/I/2174yonQBtL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 17: https://m.media-amazon.com/images/I/218BCzgKxuL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 18: https://m.media-amazon.com/images/I/218BCzgKxuL.jpg
# What is the item wattage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 19: https://m.media-amazon.com/images/I/218BCzgKxuL.jpg
# What is the item voltage? Mention the unit too
# 208-240v 16a
# 20: https://m.media-amazon.com/images/I/21BMc5GC4iL.jpg
# What is the item width? Mention the unit too
# 50cm
# 21: https://m.media-amazon.com/images/I/21CxlWbim3L.jpg
# What is the item width? Mention the unit too
# 12"
# 22: https://m.media-amazon.com/images/I/21DZ7BAZ6-L.jpg
# What is the item item_volume? Mention the unit too
# 1.75 oz
# 23: https://m.media-amazon.com/images/I/21GLFXwC1mS.jpg
# What is the item width? Mention the unit too
# 52 cm
# 24: https://m.media-amazon.com/images/I/21GLFXwC1mS.jpg
# What is the item depth? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 25: https://m.media-amazon.com/images/I/21H+7R85YZL.jpg
# What is the item width? Mention the unit too
# 9 cm
# 26: https://m.media-amazon.com/images/I/21H+7R85YZL.jpg
# What is the item depth? Mention the unit too
# 3.5 in
# 27: https://m.media-amazon.com/images/I/21IGmiJi-PL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 28: https://m.media-amazon.com/images/I/21Is45vdL0L.jpg
# What is the item net weight? Mention the unit too
# 0.096kg
# 29: https://m.media-amazon.com/images/I/21Raw7jSIML.jpg
# What is the item net weight? Mention the unit too
# 2.62 lbs
# 30: https://m.media-amazon.com/images/I/21Vc5ixqKpS.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 31: https://m.media-amazon.com/images/I/21W7FvftSCL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 32: https://m.media-amazon.com/images/I/21aD6ktvwxS.jpg
# What is the item width? Mention the unit too
# 5.8 in 14 cm
# 33: https://m.media-amazon.com/images/I/21aD6ktvwxS.jpg
# What is the item depth? Mention the unit too
# 5.8 in 14 cm
# 34: https://m.media-amazon.com/images/I/21aD6ktvwxS.jpg
# What is the item height? Mention the unit too
# 5.8 in 14 cm
# 35: https://m.media-amazon.com/images/I/21bfrFeArAL.jpg
# What is the item net weight? Mention the unit too
# 3 lbs
# 36: https://m.media-amazon.com/images/I/21bwWoCpGJL.jpg
# What is the item height? Mention the unit too
# 3.28"
# 37: https://m.media-amazon.com/images/I/21cLufe8Y5L.jpg
# What is the item voltage? Mention the unit too
# unanswerable
# 38: https://m.media-amazon.com/images/I/21cLufe8Y5L.jpg
# What is the item wattage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 39: https://m.media-amazon.com/images/I/21d6Dtc94mL.jpg
# What is the item depth? Mention the unit too
# 1.5
# 40: https://m.media-amazon.com/images/I/21d6Dtc94mL.jpg
# What is the item width? Mention the unit too
# 51.2 in
# 41: https://m.media-amazon.com/images/I/21fIe0wHxDL.jpg
# What is the item height? Mention the unit too
# 6
# 42: https://m.media-amazon.com/images/I/21jOOqo0oZL.jpg
# What is the item width? Mention the unit too
# 96 in
# 43: https://m.media-amazon.com/images/I/21jOOqo0oZL.jpg
# What is the item height? Mention the unit too
# 48 in 122 cm
# 44: https://m.media-amazon.com/images/I/21lqVGTzV1L.jpg
# What is the item height? Mention the unit too
# 40 cm 25.6 in
# 45: https://m.media-amazon.com/images/I/21m65YQrQdL.jpg
# What is the item depth? Mention the unit too
# 3.1 in
# 46: https://m.media-amazon.com/images/I/21m65YQrQdL.jpg
# What is the item height? Mention the unit too
# 5.8 in
# 47: https://m.media-amazon.com/images/I/21m65YQrQdL.jpg
# What is the item width? Mention the unit too
# 5.8 in
# 48: https://m.media-amazon.com/images/I/21nEy7KBQlL.jpg
# What is the item width? Mention the unit too
# 48 in 120 cm
# 49: https://m.media-amazon.com/images/I/21nEy7KBQlL.jpg
# What is the item depth? Mention the unit too
# 1.5 in
# 50: https://m.media-amazon.com/images/I/21nEy7KBQlL.jpg
# What is the item height? Mention the unit too
# 55 in 90 cm
# 51: https://m.media-amazon.com/images/I/21pFwZ8ghkL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 52: https://m.media-amazon.com/images/I/21pFwZ8ghkL.jpg
# What is the item wattage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 53: https://m.media-amazon.com/images/I/21qcJWXFNkL.jpg
# What is the item depth? Mention the unit too
# 5 in / 12.5 cm
# 54: https://m.media-amazon.com/images/I/21qcJWXFNkL.jpg
# What is the item height? Mention the unit too
# 7.08 in 18 cm
# 55: https://m.media-amazon.com/images/I/21qgWY60ABL.jpg
# What is the item width? Mention the unit too
# 96.20cm
# 56: https://m.media-amazon.com/images/I/21qleENrBBL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 57: https://m.media-amazon.com/images/I/21s+qly8nXL.jpg
# What is the item depth? Mention the unit too
# 1.5
# 58: https://m.media-amazon.com/images/I/21s+qly8nXL.jpg
# What is the item width? Mention the unit too
# 51.2 in
# 59: https://m.media-amazon.com/images/I/21tOerzlVML.jpg
# What is the item wattage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 60: https://m.media-amazon.com/images/I/21tOerzlVML.jpg
# What is the item voltage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 61: https://m.media-amazon.com/images/I/21twwj6e-VL.jpg
# What is the item net weight? Mention the unit too
# 160g
# 62: https://m.media-amazon.com/images/I/21vCDAVwSXS.jpg
# What is the item height? Mention the unit too
# 1000mm
# 63: https://m.media-amazon.com/images/I/21vCDAVwSXS.jpg
# What is the item depth? Mention the unit too
# 150
# 64: https://m.media-amazon.com/images/I/21vCDAVwSXS.jpg
# What is the item width? Mention the unit too
# 200mm
# 65: https://m.media-amazon.com/images/I/21vv80MKQEL.jpg
# What is the item voltage? Mention the unit too
# 3.7v
# 66: https://m.media-amazon.com/images/I/21xX4tzOqKL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 67: https://m.media-amazon.com/images/I/21xnCHoPZHL.jpg
# What is the item height? Mention the unit too
# 79-157
# 68: https://m.media-amazon.com/images/I/21ykCJJsDpL.jpg
# What is the item width? Mention the unit too
# 4.2 in
# 69: https://m.media-amazon.com/images/I/21ykCJJsDpL.jpg
# What is the item height? Mention the unit too
# 4.2 in 10 cm
# 70: https://m.media-amazon.com/images/I/21ykCJJsDpL.jpg
# What is the item depth? Mention the unit too
# 4.2 in
# 71: https://m.media-amazon.com/images/I/21ztnqtFNVL.jpg
# What is the item width? Mention the unit too
# 9.1 in
# 72: https://m.media-amazon.com/images/I/21ztnqtFNVL.jpg
# What is the item height? Mention the unit too
# 9.1 in 23 cm
# 73: https://m.media-amazon.com/images/I/21ztnqtFNVL.jpg
# What is the item depth? Mention the unit too
# 23 cm
# 74: https://m.media-amazon.com/images/I/31+1xiVjZBL.jpg
# What is the item wattage? Mention the unit too
# 1500w
# 75: https://m.media-amazon.com/images/I/31+1xiVjZBL.jpg
# What is the item voltage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 76: https://m.media-amazon.com/images/I/31+21njYcOL.jpg
# What is the item height? Mention the unit too
# 4.7 in / 12 cm
# 77: https://m.media-amazon.com/images/I/31+21njYcOL.jpg
# What is the item depth? Mention the unit too
# 3.1 in / 8 cm
# 78: https://m.media-amazon.com/images/I/31+B4SvByXL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 79: https://m.media-amazon.com/images/I/31+H+PVsNEL.jpg
# What is the item height? Mention the unit too
# 50cm
# 80: https://m.media-amazon.com/images/I/31+KMtY+QXL.jpg
# What is the item net weight? Mention the unit too
# 16 oz
# 81: https://m.media-amazon.com/images/I/31+KPbkPVPL.jpg
# What is the item net weight? Mention the unit too
# 243 lbs
# 82: https://m.media-amazon.com/images/I/31+NHijx4tL.jpg
# What is the item net weight? Mention the unit too
# 5.05 kg
# 83: https://m.media-amazon.com/images/I/31+RAxx7XaL.jpg
# What is the item net weight? Mention the unit too
# 10 oz
# 84: https://m.media-amazon.com/images/I/31+X1Lh3+eL.jpg
# What is the item height? Mention the unit too
# 39 in 98 cm
# 85: https://m.media-amazon.com/images/I/31+X1Lh3+eL.jpg
# What is the item width? Mention the unit too
# 39 in 98 cm
# 86: https://m.media-amazon.com/images/I/31+X1Lh3+eL.jpg
# What is the item depth? Mention the unit too
# 39 in 58 cm
# 87: https://m.media-amazon.com/images/I/31+kevQrOnL.jpg
# What is the item wattage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 88: https://m.media-amazon.com/images/I/31+kevQrOnL.jpg
# What is the item voltage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 89: https://m.media-amazon.com/images/I/31+kevQrOnL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 90: https://m.media-amazon.com/images/I/31+nz2egbjL.jpg
# What is the item width? Mention the unit too
# 20 cm
# 91: https://m.media-amazon.com/images/I/31+qzYwhJ9L.jpg
# What is the item net weight? Mention the unit too
# 200 lbs
# 92: https://m.media-amazon.com/images/I/31+sbhHNfYS.jpg
# What is the item width? Mention the unit too
# 400 mm
# 93: https://m.media-amazon.com/images/I/31+zGAugKrL.jpg
# What is the item height? Mention the unit too
# 23.95
# 94: https://m.media-amazon.com/images/I/31+zdbOuiTL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 95: https://m.media-amazon.com/images/I/31-4a-yI8sS.jpg
# What is the item height? Mention the unit too
# 5.51 in
# 96: https://m.media-amazon.com/images/I/31-4a-yI8sS.jpg
# What is the item width? Mention the unit too
# 12.5cm
# 97: https://m.media-amazon.com/images/I/31-4uQ1S2XL.jpg
# What is the item voltage? Mention the unit too
# 5.6v
# 98: https://m.media-amazon.com/images/I/31-7OAd1COL.jpg
# What is the item height? Mention the unit too
# 3.5 cm(1.4")
# 80 cm(31.5")
# 2.5 cm(1.0")
# 99: https://m.media-amazon.com/images/I/31-8fLBjX8L.jpg
# What is the item depth? Mention the unit too
# 4.33 in / 11 cm
# 100: https://m.media-amazon.com/images/I/31-A90GRAHL.jpg
# What is the item height? Mention the unit too
# 5.7in 14.6in
# 101: https://m.media-amazon.com/images/I/31-Jdk3SMUL.jpg
# What is the item item_volume? Mention the unit too
# 2 fl oz
# 102: https://m.media-amazon.com/images/I/31-OBkMKDLL.jpg
# What is the item wattage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 103: https://m.media-amazon.com/images/I/31-QiMl+gwL.jpg
# What is the item width? Mention the unit too
# 86 cm
# 104: https://m.media-amazon.com/images/I/31-Tp1rWTJL.jpg
# What is the item height? Mention the unit too
# 69 cm
# 105: https://m.media-amazon.com/images/I/31-Ubz8YvUL.jpg
# What is the item height? Mention the unit too
# 7.5cm
# 106: https://m.media-amazon.com/images/I/31-Ubz8YvUL.jpg
# What is the item width? Mention the unit too
# 20cm
# 107: https://m.media-amazon.com/images/I/31-UedLQDqL.jpg
# What is the item height? Mention the unit too
# 73 cm(28.7")
# 108: https://m.media-amazon.com/images/I/31-W0zT17nL.jpg
# What is the item net weight? Mention the unit too
# 8 oz
# 109: https://m.media-amazon.com/images/I/31-bBqUQPuL.jpg
# What is the item height? Mention the unit too
# 40 cm
# 30 cm
# 30 cm
# 110: https://m.media-amazon.com/images/I/310-VAupIJL.jpg
# What is the item height? Mention the unit too
# 8 cm 25 cm 80 cm
# 111: https://m.media-amazon.com/images/I/31014HApIqL.jpg
# What is the item net weight? Mention the unit too
# 10 oz
# 112: https://m.media-amazon.com/images/I/3101lgy28BL.jpg
# What is the item wattage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 113: https://m.media-amazon.com/images/I/3101lgy28BL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 114: https://m.media-amazon.com/images/I/3105qskWRcL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 115: https://m.media-amazon.com/images/I/3105qskWRcL.jpg
# What is the item wattage? Mention the unit too
# 5500w
# 116: https://m.media-amazon.com/images/I/3106Kd8KjnL.jpg
# What is the item net weight? Mention the unit too
# 1.9 oz (54g)
# 117: https://m.media-amazon.com/images/I/3106iDqsfQL.jpg
# What is the item net weight? Mention the unit too
# 5 oz (142 g)
# 118: https://m.media-amazon.com/images/I/3107VVwSyXL.jpg
# What is the item width? Mention the unit too
# 3.9in
# 119: https://m.media-amazon.com/images/I/3107VVwSyXL.jpg
# What is the item depth? Mention the unit too
# 3.9in
# 120: https://m.media-amazon.com/images/I/310BVU1bXvL.jpg
# What is the item net weight? Mention the unit too
# 108g
# 121: https://m.media-amazon.com/images/I/310GYVrrJPS.jpg
# What is the item depth? Mention the unit too
# 10.2 cm
# 122: https://m.media-amazon.com/images/I/310ICDHEK-L.jpg
# What is the item net weight? Mention the unit too
# 250g
# 123: https://m.media-amazon.com/images/I/310PNQ4FmqL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 124: https://m.media-amazon.com/images/I/310Qevq+VSL.jpg
# What is the item net weight? Mention the unit too
# 1kg
# 125: https://m.media-amazon.com/images/I/310Th3tbqRL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 126: https://m.media-amazon.com/images/I/310Th3tbqRL.jpg
# What is the item voltage? Mention the unit too
# 12v
# 127: https://m.media-amazon.com/images/I/310Tz9gnk2L.jpg
# What is the item height? Mention the unit too
# 191cm
# 128: https://m.media-amazon.com/images/I/310VuJknGFS.jpg
# What is the item width? Mention the unit too
# 90 cm
# 129: https://m.media-amazon.com/images/I/310X-ftA6SL.jpg
# What is the item net weight? Mention the unit too
# 7.8 lbs
# 130: https://m.media-amazon.com/images/I/310YvVAYofL.jpg
# What is the item width? Mention the unit too
# 31 cm
# 131: https://m.media-amazon.com/images/I/310aYU-JigL.jpg
# What is the item width? Mention the unit too
# 65cm
# 132: https://m.media-amazon.com/images/I/310aYU-JigL.jpg
# What is the item height? Mention the unit too
# 25.6in(65cm)
# 133: https://m.media-amazon.com/images/I/310aYU-JigL.jpg
# What is the item depth? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 134: https://m.media-amazon.com/images/I/310dh1DQxRL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 135: https://m.media-amazon.com/images/I/310hyjPrgML.jpg
# What is the item height? Mention the unit too
# 20.0 cm
# 136: https://m.media-amazon.com/images/I/310hyjPrgML.jpg
# What is the item depth? Mention the unit too
# 2.9 cm
# 137: https://m.media-amazon.com/images/I/310kcUKMHOL.jpg
# What is the item height? Mention the unit too
# 26cm
# 138: https://m.media-amazon.com/images/I/310mwtoWn3L.jpg
# What is the item height? Mention the unit too
# 29.05 cm
# 139: https://m.media-amazon.com/images/I/310oxdFmgLL.jpg
# What is the item width? Mention the unit too
# 100mm/3.93in
# 140: https://m.media-amazon.com/images/I/310oxdFmgLL.jpg
# What is the item depth? Mention the unit too
# 11.5mm/0.45in
# 141: https://m.media-amazon.com/images/I/310p+AOeZ6L.jpg
# What is the item height? Mention the unit too
# 14cm
# 142: https://m.media-amazon.com/images/I/310qlaeUSAL.jpg
# What is the item depth? Mention the unit too
# 33.5
# 143: https://m.media-amazon.com/images/I/310qlaeUSAL.jpg
# What is the item width? Mention the unit too
# 33 in 83.5 cm
# 144: https://m.media-amazon.com/images/I/310rX4WoAFL.jpg
# What is the item depth? Mention the unit too
# 3.9in
# 145: https://m.media-amazon.com/images/I/310rX4WoAFL.jpg
# What is the item height? Mention the unit too
# 90cm/35.4in
# 146: https://m.media-amazon.com/images/I/310rX4WoAFL.jpg
# What is the item width? Mention the unit too
# 10cm
# 147: https://m.media-amazon.com/images/I/310uxz1C1+L.jpg
# What is the item item_volume? Mention the unit too
# 20
# 148: https://m.media-amazon.com/images/I/311+pYVZ1zL.jpg
# What is the item width? Mention the unit too
# 50cm
# 149: https://m.media-amazon.com/images/I/311+pYVZ1zL.jpg
# What is the item depth? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 150: https://m.media-amazon.com/images/I/3111QvQTfJL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 151: https://m.media-amazon.com/images/I/3113NMTt2CL.jpg
# What is the item height? Mention the unit too
# 74.5
# 152: https://m.media-amazon.com/images/I/3118BjQXgAL.jpg
# What is the item depth? Mention the unit too
# 3.14 in / 8 cm
# 153: https://m.media-amazon.com/images/I/3118BjQXgAL.jpg
# What is the item height? Mention the unit too
# 7.86 in / 20 cm
# 154: https://m.media-amazon.com/images/I/31196HWGAjL.jpg
# What is the item width? Mention the unit too
# 5cm
# 10cm
# 155: https://m.media-amazon.com/images/I/31196HWGAjL.jpg
# What is the item height? Mention the unit too
# 5cm
# 10cm
# 156: https://m.media-amazon.com/images/I/311JBecauYL.jpg
# What is the item width? Mention the unit too
# 35mm
# 157: https://m.media-amazon.com/images/I/311KCsFxw9L.jpg
# What is the item width? Mention the unit too
# 74
# 158: https://m.media-amazon.com/images/I/311KCsFxw9L.jpg
# What is the item height? Mention the unit too
# 30.3
# 159: https://m.media-amazon.com/images/I/311KDyOGX-L.jpg
# What is the item net weight? Mention the unit too
# 2.31lb
# 160: https://m.media-amazon.com/images/I/311M6XKGJhL.jpg
# What is the item height? Mention the unit too
# 25*13cm
# 161: https://m.media-amazon.com/images/I/311PssCBQIL.jpg
# What is the item item_volume? Mention the unit too
# 24 oz
# 162: https://m.media-amazon.com/images/I/311UTstDjGL.jpg
# What is the item height? Mention the unit too
# 82cm
# 163: https://m.media-amazon.com/images/I/311ZqD+0WiL.jpg
# What is the item width? Mention the unit too
# 80
# 164: https://m.media-amazon.com/images/I/311d86W-TPL.jpg
# What is the item net weight? Mention the unit too
# 250g
# 165: https://m.media-amazon.com/images/I/311dT7UohfS.jpg
# What is the item voltage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 166: https://m.media-amazon.com/images/I/311dT7UohfS.jpg
# What is the item wattage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 167: https://m.media-amazon.com/images/I/311e8av9T8L.jpg
# What is the item net weight? Mention the unit too
# 6kg
# 168: https://m.media-amazon.com/images/I/311lBTY41pL.jpg
# What is the item width? Mention the unit too
# 10.5
# 169: https://m.media-amazon.com/images/I/311lBTY41pL.jpg
# What is the item depth? Mention the unit too
# 10.5
# 170: https://m.media-amazon.com/images/I/311nVBb35CL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 171: https://m.media-amazon.com/images/I/311qj00+z6L.jpg
# What is the item height? Mention the unit too
# 33.1
# 172: https://m.media-amazon.com/images/I/311uqJG-v3L.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 173: https://m.media-amazon.com/images/I/3121-R7e6gL.jpg
# What is the item width? Mention the unit too
# 1.1 in / 3.2 cm
# 174: https://m.media-amazon.com/images/I/3121-R7e6gL.jpg
# What is the item height? Mention the unit too
# 1.1 in / 3.2 cm
# 175: https://m.media-amazon.com/images/I/312BjPAAlcL.jpg
# What is the item width? Mention the unit too
# 14cm
# 176: https://m.media-amazon.com/images/I/312DIk+dXDL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 177: https://m.media-amazon.com/images/I/312aMY3cO9L.jpg
# What is the item depth? Mention the unit too
# 0.75inch
# 178: https://m.media-amazon.com/images/I/312ux4Npq5L.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 179: https://m.media-amazon.com/images/I/3130yji+ASL.jpg
# What is the item depth? Mention the unit too
# 1.1 in / 3.0 cm
# 180: https://m.media-amazon.com/images/I/3130yji+ASL.jpg
# What is the item width? Mention the unit too
# 1.1 in / 3.0 cm
# 181: https://m.media-amazon.com/images/I/3131mkESkQL.jpg
# What is the item net weight? Mention the unit too
# 32 oz (2 lbs) 908 g
# 182: https://m.media-amazon.com/images/I/3136hKrB0xS.jpg
# What is the item height? Mention the unit too
# 74,5 cm
# 183: https://m.media-amazon.com/images/I/313H+KOefpL.jpg
# What is the item wattage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 184: https://m.media-amazon.com/images/I/313H+KOefpL.jpg
# What is the item voltage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 185: https://m.media-amazon.com/images/I/313P9jCeUEL.jpg
# What is the item net weight? Mention the unit too
# 100
# 186: https://m.media-amazon.com/images/I/313PqxvaGFL.jpg
# What is the item width? Mention the unit too
# 5.08cm/2inch
# 187: https://m.media-amazon.com/images/I/313PqxvaGFL.jpg
# What is the item depth? Mention the unit too
# 2.83inch
# 188: https://m.media-amazon.com/images/I/313Y-Pmq5OL.jpg
# What is the item height? Mention the unit too
# 2.7 in / 7.0 cm
# 189: https://m.media-amazon.com/images/I/313Y-Pmq5OL.jpg
# What is the item depth? Mention the unit too
# 11.0 in / 28.0 cm
# 190: https://m.media-amazon.com/images/I/313ZWJXgMXL.jpg
# What is the item net weight? Mention the unit too
# 0.35 oz
# 191: https://m.media-amazon.com/images/I/313cKYWS+nL.jpg
# What is the item depth? Mention the unit too
# 40cm, 40cm
# 192: https://m.media-amazon.com/images/I/313cKYWS+nL.jpg
# What is the item height? Mention the unit too
# 40cm 60cm
# 193: https://m.media-amazon.com/images/I/313gsCHpfeL.jpg
# What is the item net weight? Mention the unit too
# 6.2 lbs
# 194: https://m.media-amazon.com/images/I/313h5LWmlcL.jpg
# What is the item height? Mention the unit too
# 127.5 cm
# 195: https://m.media-amazon.com/images/I/313iZcTsPNL.jpg
# What is the item height? Mention the unit too
# 27.4cm
# 196: https://m.media-amazon.com/images/I/313iZcTsPNL.jpg
# What is the item width? Mention the unit too
# 33.3cm
# 197: https://m.media-amazon.com/images/I/313rlTwmR9L.jpg
# What is the item net weight? Mention the unit too
# 40lb
# 198: https://m.media-amazon.com/images/I/313sSWfiIYL.jpg
# What is the item net weight? Mention the unit too
# 33grams
# 199: https://m.media-amazon.com/images/I/3141MAkuatL.jpg
# What is the item net weight? Mention the unit too
# 14 oz (425 g)
# 200: https://m.media-amazon.com/images/I/31445Xcd2XL.jpg
# What is the item height? Mention the unit too
# 37.5cm/14.76in
# 201: https://m.media-amazon.com/images/I/31445Xcd2XL.jpg
# What is the item depth? Mention the unit too
# 14.76in
# 202: https://m.media-amazon.com/images/I/31445Xcd2XL.jpg
# What is the item width? Mention the unit too
# 14.76in
# 203: https://m.media-amazon.com/images/I/3145h9GZigL.jpg
# What is the item height? Mention the unit too
# 13.2 in
# 204: https://m.media-amazon.com/images/I/3145h9GZigL.jpg
# What is the item depth? Mention the unit too
# 7.4 in
# 205: https://m.media-amazon.com/images/I/3147F5NHEdL.jpg
# What is the item wattage? Mention the unit too
# 1200w
# 206: https://m.media-amazon.com/images/I/3147F5NHEdL.jpg
# What is the item voltage? Mention the unit too
# 120v
# 207: https://m.media-amazon.com/images/I/31489jH+cnL.jpg
# What is the item height? Mention the unit too
# 15.75 inches
# 208: https://m.media-amazon.com/images/I/314FxsDUTFL.jpg
# What is the item net weight? Mention the unit too
# 226g
# 209: https://m.media-amazon.com/images/I/314Gwp04mYL.jpg
# What is the item net weight? Mention the unit too
# 11.8kg
# 210: https://m.media-amazon.com/images/I/314J9z-v4HL.jpg
# What is the item depth? Mention the unit too
# 91mm
# 211: https://m.media-amazon.com/images/I/314NPHTZhwL.jpg
# What is the item net weight? Mention the unit too
# 130g
# 212: https://m.media-amazon.com/images/I/314VKLwLwYL.jpg
# What is the item height? Mention the unit too
# 128cm
# 213: https://m.media-amazon.com/images/I/314gI8VlFOL.jpg
# What is the item voltage? Mention the unit too
# 5v 1a
# 214: https://m.media-amazon.com/images/I/314oOH7ICvS.jpg
# What is the item width? Mention the unit too
# 60 cm
# 215: https://m.media-amazon.com/images/I/314oOH7ICvS.jpg
# What is the item height? Mention the unit too
# 135.5 cm
# 216: https://m.media-amazon.com/images/I/314p2NKHdLL.jpg
# What is the item voltage? Mention the unit too
# 12v
# 217: https://m.media-amazon.com/images/I/314p2NKHdLL.jpg
# What is the item wattage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 218: https://m.media-amazon.com/images/I/314p2NKHdLL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 219: https://m.media-amazon.com/images/I/314p4MOJlRL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 220: https://m.media-amazon.com/images/I/314vPdiXQFL.jpg
# What is the item depth? Mention the unit too
# 2.7 cm
# 221: https://m.media-amazon.com/images/I/314vPdiXQFL.jpg
# What is the item height? Mention the unit too
# 1.1 inch 2.7 cm
# 222: https://m.media-amazon.com/images/I/314wRJd39EL.jpg
# What is the item height? Mention the unit too
# 43.18cm
# 223: https://m.media-amazon.com/images/I/314xpT+zaWL.jpg
# What is the item net weight? Mention the unit too
# 50.7 lbs
# 224: https://m.media-amazon.com/images/I/3158RU753EL.jpg
# What is the item depth? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 225: https://m.media-amazon.com/images/I/3158RU753EL.jpg
# What is the item width? Mention the unit too
# 3ft wide
# 226: https://m.media-amazon.com/images/I/315C1CvRpTL.jpg
# What is the item height? Mention the unit too
# 19.5cm
# 227: https://m.media-amazon.com/images/I/315G27PSLxL.jpg
# What is the item net weight? Mention the unit too
# 113 g
# 228: https://m.media-amazon.com/images/I/315Mb5z2+RL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 229: https://m.media-amazon.com/images/I/315PtJZRiFL.jpg
# What is the item wattage? Mention the unit too
# 400
# 230: https://m.media-amazon.com/images/I/315PtJZRiFL.jpg
# What is the item voltage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 231: https://m.media-amazon.com/images/I/315QF8BudHL.jpg
# What is the item height? Mention the unit too
# 10 cm
# 232: https://m.media-amazon.com/images/I/315SSiZLghL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 233: https://m.media-amazon.com/images/I/315T7LAYrLL.jpg
# What is the item width? Mention the unit too
# 70 cm
# 234: https://m.media-amazon.com/images/I/315T7LAYrLL.jpg
# What is the item depth? Mention the unit too
# 70 cm
# 235: https://m.media-amazon.com/images/I/315YvNM5jML.jpg
# What is the item width? Mention the unit too
# 42.1
# 236: https://m.media-amazon.com/images/I/315ZwdYq-nL.jpg
# What is the item width? Mention the unit too
# 36.5 cm
# 237: https://m.media-amazon.com/images/I/315b6Zdm7BL.jpg
# What is the item width? Mention the unit too
# 25 cm
# 238: https://m.media-amazon.com/images/I/315b6Zdm7BL.jpg
# What is the item depth? Mention the unit too
# 25 cm
# 239: https://m.media-amazon.com/images/I/315ldex3oEL.jpg
# What is the item height? Mention the unit too
# 33.5 cm
# 240: https://m.media-amazon.com/images/I/315ldex3oEL.jpg
# What is the item width? Mention the unit too
# 60 cm
# 241: https://m.media-amazon.com/images/I/315y3qqHQ1L.jpg
# What is the item height? Mention the unit too
# 180 cm (70.8")
# 242: https://m.media-amazon.com/images/I/315yDUfDBgL.jpg
# What is the item height? Mention the unit too
# 7cm/2.75in
# 243: https://m.media-amazon.com/images/I/315yDUfDBgL.jpg
# What is the item depth? Mention the unit too
# 7cm/2.75in
# 244: https://m.media-amazon.com/images/I/3162jbDKLhL.jpg
# What is the item depth? Mention the unit too
# 3.3 in / 8.5 cm
# 245: https://m.media-amazon.com/images/I/31655QolL+L.jpg
# What is the item depth? Mention the unit too
# 7.6 cm
# 246: https://m.media-amazon.com/images/I/31655QolL+L.jpg
# What is the item width? Mention the unit too
# 15.5 cm
# 247: https://m.media-amazon.com/images/I/316JmynwTeL.jpg
# What is the item height? Mention the unit too
# 27.76 in 70.5 cm
# 248: https://m.media-amazon.com/images/I/316PuR+4P7L.jpg
# What is the item width? Mention the unit too
# 35 cm(13.8" )
# 249: https://m.media-amazon.com/images/I/316QBt0qRVL.jpg
# What is the item width? Mention the unit too
# 2.32 in / 5.9 cm
# 250: https://m.media-amazon.com/images/I/316QBt0qRVL.jpg
# What is the item depth? Mention the unit too
# 2.32 in / 5.9 cm
# 251: https://m.media-amazon.com/images/I/316QheTdnoL.jpg
# What is the item width? Mention the unit too
# 45
# 252: https://m.media-amazon.com/images/I/316X4m00znL.jpg
# What is the item net weight? Mention the unit too
# 100 g
# 253: https://m.media-amazon.com/images/I/316cJ-vBGqL.jpg
# What is the item item_volume? Mention the unit too
# 1.2 fl oz
# 254: https://m.media-amazon.com/images/I/316iYciADUL.jpg
# What is the item depth? Mention the unit too
# 35 cm
# 255: https://m.media-amazon.com/images/I/316pJ84mB-S.jpg
# What is the item depth? Mention the unit too
# 6.29
# 256: https://m.media-amazon.com/images/I/316pJ84mB-S.jpg
# What is the item height? Mention the unit too
# 6.29
# 257: https://m.media-amazon.com/images/I/316pJ84mB-S.jpg
# What is the item width? Mention the unit too
# 6
# 258: https://m.media-amazon.com/images/I/316rD0Fy5eL.jpg
# What is the item width? Mention the unit too
# 76 cm
# 205 cm
# 259: https://m.media-amazon.com/images/I/316rD0Fy5eL.jpg
# What is the item depth? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 260: https://m.media-amazon.com/images/I/316rYL2JOBL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 261: https://m.media-amazon.com/images/I/316rYL2JOBL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 262: https://m.media-amazon.com/images/I/316vEjFHFXL.jpg
# What is the item width? Mention the unit too
# 45 cm
# 35,5 cm
# 80 cm
# 263: https://m.media-amazon.com/images/I/317+4WLmMhL.jpg
# What is the item width? Mention the unit too
# 22
# 264: https://m.media-amazon.com/images/I/317+4WLmMhL.jpg
# What is the item height? Mention the unit too
# 39
# 265: https://m.media-amazon.com/images/I/3179bFOeHPL.jpg
# What is the item height? Mention the unit too
# 2.55 in / 6.5 cm
# 266: https://m.media-amazon.com/images/I/3179bFOeHPL.jpg
# What is the item depth? Mention the unit too
# 2.3 in / 6 cm
# 267: https://m.media-amazon.com/images/I/3179z0kjMBL.jpg
# What is the item height? Mention the unit too
# 9.8 in 25 cm
# 268: https://m.media-amazon.com/images/I/317H4RZWLvL.jpg
# What is the item width? Mention the unit too
# 8 cm
# 269: https://m.media-amazon.com/images/I/317H4RZWLvL.jpg
# What is the item depth? Mention the unit too
# 8 cm
# 270: https://m.media-amazon.com/images/I/317JgcKuEKL.jpg
# What is the item height? Mention the unit too
# 5.90 in / 15 cm
# 271: https://m.media-amazon.com/images/I/317JgcKuEKL.jpg
# What is the item width? Mention the unit too
# 2.75 in / 7 cm
# 272: https://m.media-amazon.com/images/I/317JgcKuEKL.jpg
# What is the item depth? Mention the unit too
# 2.75 in / 7 cm
# 273: https://m.media-amazon.com/images/I/317K7+0KVPL.jpg
# What is the item net weight? Mention the unit too
# 500 g
# 274: https://m.media-amazon.com/images/I/317UEfHNWFL.jpg
# What is the item height? Mention the unit too
# 1.5 in / 4.0 cm
# 275: https://m.media-amazon.com/images/I/317UEfHNWFL.jpg
# What is the item depth? Mention the unit too
# 1.5 in / 4.0 cm
# 276: https://m.media-amazon.com/images/I/317V84vTmRL.jpg
# What is the item net weight? Mention the unit too
# 8 oz
# 277: https://m.media-amazon.com/images/I/317e7XKMYmS.jpg
# What is the item wattage? Mention the unit too
# 1.50w
# 278: https://m.media-amazon.com/images/I/317e7XKMYmS.jpg
# What is the item voltage? Mention the unit too
# 12v
# 279: https://m.media-amazon.com/images/I/317to6OSbEL.jpg
# What is the item depth? Mention the unit too
# 1.9 in / 5.0 cm
# 280: https://m.media-amazon.com/images/I/317to6OSbEL.jpg
# What is the item height? Mention the unit too
# 8.2 in / 21 cm
# 281: https://m.media-amazon.com/images/I/3182q3TzyTL.jpg
# What is the item net weight? Mention the unit too
# 190g
# 282: https://m.media-amazon.com/images/I/3187NaQvGVL.jpg
# What is the item depth? Mention the unit too
# 5.8 in 14 cm
# 283: https://m.media-amazon.com/images/I/3187NaQvGVL.jpg
# What is the item width? Mention the unit too
# 5.8 in 14 cm
# 284: https://m.media-amazon.com/images/I/318JGZzqQLL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 285: https://m.media-amazon.com/images/I/318NkZYUxbL.jpg
# What is the item height? Mention the unit too
# 16.5cm
# 286: https://m.media-amazon.com/images/I/318R0lcGWuL.jpg
# What is the item width? Mention the unit too
# 10.63 in 27 cm
# 287: https://m.media-amazon.com/images/I/318TVw4iM1L.jpg
# What is the item voltage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 288: https://m.media-amazon.com/images/I/318VrqotQiL.jpg
# What is the item depth? Mention the unit too
# 3.5"
# 289: https://m.media-amazon.com/images/I/318VrqotQiL.jpg
# What is the item height? Mention the unit too
# 8"
# 3.5"
# 290: https://m.media-amazon.com/images/I/318Vs-v1K+L.jpg
# What is the item net weight? Mention the unit too
# 3.75 oz
# 291: https://m.media-amazon.com/images/I/318qeLWHofS.jpg
# What is the item height? Mention the unit too
# 39cm 15.3in
# 292: https://m.media-amazon.com/images/I/318qeLWHofS.jpg
# What is the item depth? Mention the unit too
# 3.5 in
# 293: https://m.media-amazon.com/images/I/318rqdGipZL.jpg
# What is the item net weight? Mention the unit too
# 965g
# 294: https://m.media-amazon.com/images/I/319+HHdREmL.jpg
# What is the item depth? Mention the unit too
# 2.55 in / 6.5 cm
# 295: https://m.media-amazon.com/images/I/319+HHdREmL.jpg
# What is the item width? Mention the unit too
# 4.4 in / 11.2 cm
# 296: https://m.media-amazon.com/images/I/31933u5NyqL.jpg
# What is the item width? Mention the unit too
# 44.88
# 297: https://m.media-amazon.com/images/I/3196JaAmUXL.jpg
# What is the item height? Mention the unit too
# 63"
# 298: https://m.media-amazon.com/images/I/319PRYi9q9L.jpg
# What is the item wattage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 299: https://m.media-amazon.com/images/I/319PRYi9q9L.jpg
# What is the item voltage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 300: https://m.media-amazon.com/images/I/319RcGrykvS.jpg
# What is the item voltage? Mention the unit too
# v
# 301: https://m.media-amazon.com/images/I/319Utc-4JCL.jpg
# What is the item voltage? Mention the unit too
# 230v 750w
# 302: https://m.media-amazon.com/images/I/319Utc-4JCL.jpg
# What is the item wattage? Mention the unit too
# 250
# 303: https://m.media-amazon.com/images/I/319Utc-4JCL.jpg
# What is the item net weight? Mention the unit too
# 2.6kg
# 304: https://m.media-amazon.com/images/I/319YtUP6CdL.jpg
# What is the item depth? Mention the unit too
# 1.2cm/0.47inch
# 305: https://m.media-amazon.com/images/I/319bXpAHHGL.jpg
# What is the item depth? Mention the unit too
# 160mm, 300mm
# 306: https://m.media-amazon.com/images/I/319gwo27y5L.jpg
# What is the item net weight? Mention the unit too
# 100g
# 307: https://m.media-amazon.com/images/I/319mQCR3drL.jpg
# What is the item height? Mention the unit too
# 23.6 in (60 cm)
# 308: https://m.media-amazon.com/images/I/319mw37uGgS.jpg
# What is the item net weight? Mention the unit too
# 45 lb
# 309: https://m.media-amazon.com/images/I/319rBAua1EL.jpg
# What is the item depth? Mention the unit too
# 1.8 in / 4.5 cm
# 310: https://m.media-amazon.com/images/I/319rBAua1EL.jpg
# What is the item width? Mention the unit too
# 1.8 in / 4.5 cm
# 311: https://m.media-amazon.com/images/I/31A-FrsRYJL.jpg
# What is the item width? Mention the unit too
# 35.5 cm
# 312: https://m.media-amazon.com/images/I/31A9glDJniL.jpg
# What is the item net weight? Mention the unit too
# 3.75lbs
# 313: https://m.media-amazon.com/images/I/31AFs00-iML.jpg
# What is the item net weight? Mention the unit too
# 5 oz
# 314: https://m.media-amazon.com/images/I/31ALW6ILdNS.jpg
# What is the item depth? Mention the unit too
# 5.0cm/1.96in
# 315: https://m.media-amazon.com/images/I/31ALW6ILdNS.jpg
# What is the item height? Mention the unit too
# 8.3in
# 316: https://m.media-amazon.com/images/I/31ALW6ILdNS.jpg
# What is the item width? Mention the unit too
# 5.0cm/1.96in
# 317: https://m.media-amazon.com/images/I/31AQgkAeoeS.jpg
# What is the item depth? Mention the unit too
# 7.5cm
# 318: https://m.media-amazon.com/images/I/31AQgkAeoeS.jpg
# What is the item width? Mention the unit too
# 15.2cm
# 319: https://m.media-amazon.com/images/I/31AW7fENOoL.jpg
# What is the item net weight? Mention the unit too
# 1.7kg/1700g
# 320: https://m.media-amazon.com/images/I/31AbZL7hGVS.jpg
# What is the item height? Mention the unit too
# 7.5cm/2.95in
# 321: https://m.media-amazon.com/images/I/31AbZL7hGVS.jpg
# What is the item depth? Mention the unit too
# 7.5cm/2.95in
# 322: https://m.media-amazon.com/images/I/31AcYMtb32L.jpg
# What is the item height? Mention the unit too
# 15.8
# 323: https://m.media-amazon.com/images/I/31AnSDFDuuL.jpg
# What is the item voltage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 324: https://m.media-amazon.com/images/I/31AnSDFDuuL.jpg
# What is the item wattage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 325: https://m.media-amazon.com/images/I/31AwVD2u6yS.jpg
# What is the item depth? Mention the unit too
# 11.5cm/4.53in
# 326: https://m.media-amazon.com/images/I/31AwVD2u6yS.jpg
# What is the item height? Mention the unit too
# 15.5cm/6.1in
# 327: https://m.media-amazon.com/images/I/31AwaGMCddL.jpg
# What is the item depth? Mention the unit too
# 7cm
# 328: https://m.media-amazon.com/images/I/31AwaGMCddL.jpg
# What is the item height? Mention the unit too
# 7cm
# 329: https://m.media-amazon.com/images/I/31AwaGMCddL.jpg
# What is the item width? Mention the unit too
# 7cm
# 330: https://m.media-amazon.com/images/I/31AxondfXlL.jpg
# What is the item net weight? Mention the unit too
# 6 oz
# 331: https://m.media-amazon.com/images/I/31B-428ClQL.jpg
# What is the item net weight? Mention the unit too
# 1.4
# 332: https://m.media-amazon.com/images/I/31B2ZSdi-bS.jpg
# What is the item depth? Mention the unit too
# 5.89in
# 333: https://m.media-amazon.com/images/I/31B2ZSdi-bS.jpg
# What is the item height? Mention the unit too
# 40cm/15.72in
# 334: https://m.media-amazon.com/images/I/31B43FuEJSL.jpg
# What is the item voltage? Mention the unit too
# 120w
# 335: https://m.media-amazon.com/images/I/31B43FuEJSL.jpg
# What is the item wattage? Mention the unit too
# 120w
# 336: https://m.media-amazon.com/images/I/31B8KtbFc-L.jpg
# What is the item item_volume? Mention the unit too
# 1.35 fl oz
# 337: https://m.media-amazon.com/images/I/31BC3j4CS5L.jpg
# What is the item height? Mention the unit too
# 4.9 in / 12.5 cm
# 338: https://m.media-amazon.com/images/I/31BC3j4CS5L.jpg
# What is the item depth? Mention the unit too
# 0.7 in / 2.0 cm
# 339: https://m.media-amazon.com/images/I/31BE5BamUYS.jpg
# What is the item wattage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 340: https://m.media-amazon.com/images/I/31BE5BamUYS.jpg
# What is the item voltage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 341: https://m.media-amazon.com/images/I/31BJdvLcS2L.jpg
# What is the item net weight? Mention the unit too
# 1.93 oz
# 342: https://m.media-amazon.com/images/I/31BN3P0+FZL.jpg
# What is the item height? Mention the unit too
# 9.84
# 343: https://m.media-amazon.com/images/I/31BN3P0+FZL.jpg
# What is the item depth? Mention the unit too
# 9.84
# 344: https://m.media-amazon.com/images/I/31BN3P0+FZL.jpg
# What is the item width? Mention the unit too
# 9.84
# 345: https://m.media-amazon.com/images/I/31BVEDiDPxL.jpg
# What is the item width? Mention the unit too
# 60cm
# 346: https://m.media-amazon.com/images/I/31Bb9t5+zUL.jpg
# What is the item width? Mention the unit too
# 8.5
# 347: https://m.media-amazon.com/images/I/31Bb9t5+zUL.jpg
# What is the item depth? Mention the unit too
# 8.5cm
# 348: https://m.media-amazon.com/images/I/31Bb9t5+zUL.jpg
# What is the item height? Mention the unit too
# 17cm
# 349: https://m.media-amazon.com/images/I/31BdiRuVllL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 350: https://m.media-amazon.com/images/I/31C+5WzuXOL.jpg
# What is the item depth? Mention the unit too
# 2.8 inch 4 inch
# 351: https://m.media-amazon.com/images/I/31C+5WzuXOL.jpg
# What is the item width? Mention the unit too
# 2.8 inch
# 352: https://m.media-amazon.com/images/I/31C3Uybdh7L.jpg
# What is the item depth? Mention the unit too
# 10cm
# 353: https://m.media-amazon.com/images/I/31C3Uybdh7L.jpg
# What is the item height? Mention the unit too
# 18cm
# 354: https://m.media-amazon.com/images/I/31C4TM0tL5L.jpg
# What is the item item_volume? Mention the unit too
# 1
# 355: https://m.media-amazon.com/images/I/31C5D5F9D9S.jpg
# What is the item depth? Mention the unit too
# 2.95inch
# 356: https://m.media-amazon.com/images/I/31C5D5F9D9S.jpg
# What is the item height? Mention the unit too
# 12inch
# 357: https://m.media-amazon.com/images/I/31C8QnlC+US.jpg
# What is the item depth? Mention the unit too
# 3.1in/7.8cm
# 358: https://m.media-amazon.com/images/I/31C8QnlC+US.jpg
# What is the item width? Mention the unit too
# 5.0in/12.6cm
# 359: https://m.media-amazon.com/images/I/31CRyJdjbPL.jpg
# What is the item net weight? Mention the unit too
# 5 oz
# 360: https://m.media-amazon.com/images/I/31CUWR5Vl6L.jpg
# What is the item depth? Mention the unit too
# 0.78 in / 2 cm
# 361: https://m.media-amazon.com/images/I/31CUWR5Vl6L.jpg
# What is the item width? Mention the unit too
# 0.78 in / 2 cm
# 362: https://m.media-amazon.com/images/I/31CUkGWrSHL.jpg
# What is the item net weight? Mention the unit too
# 1050 g
# 363: https://m.media-amazon.com/images/I/31CXR2nI5xL.jpg
# What is the item net weight? Mention the unit too
# 800 lb
# 364: https://m.media-amazon.com/images/I/31Cst7vLIAL.jpg
# What is the item height? Mention the unit too
# 74cm
# 365: https://m.media-amazon.com/images/I/31CuqYq6tSL.jpg
# What is the item height? Mention the unit too
# 35 cm (14")
# 366: https://m.media-amazon.com/images/I/31CuqYq6tSL.jpg
# What is the item width? Mention the unit too
# 35 cm
# 367: https://m.media-amazon.com/images/I/31CuqYq6tSL.jpg
# What is the item depth? Mention the unit too
# 35 cm (14")
# 368: https://m.media-amazon.com/images/I/31CwBXxyu4L.jpg
# What is the item item_volume? Mention the unit too
# 10 ml
# 369: https://m.media-amazon.com/images/I/31CwvpacgHS.jpg
# What is the item width? Mention the unit too
# 24 cm 60 cm 175 cm
# 370: https://m.media-amazon.com/images/I/31Czfm+KFwL.jpg
# What is the item width? Mention the unit too
# 25,5 cm 64 cm
# 371: https://m.media-amazon.com/images/I/31Czfm+KFwL.jpg
# What is the item height? Mention the unit too
# 190 cm
# 372: https://m.media-amazon.com/images/I/31D+TJtQ3tL.jpg
# What is the item item_volume? Mention the unit too
# 10 fl oz
# 373: https://m.media-amazon.com/images/I/31D0mqjJbmL.jpg
# What is the item height? Mention the unit too
# 1.5 in / 4.0 cm
# 374: https://m.media-amazon.com/images/I/31D0mqjJbmL.jpg
# What is the item width? Mention the unit too
# 7.0 in / 17.8 cm
# 375: https://m.media-amazon.com/images/I/31DGWuERDrL.jpg
# What is the item height? Mention the unit too
# 30 cm
# 376: https://m.media-amazon.com/images/I/31DJ8wTJNML.jpg
# What is the item net weight? Mention the unit too
# 3 kg
# 377: https://m.media-amazon.com/images/I/31DKMfOhB4L.jpg
# What is the item wattage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 378: https://m.media-amazon.com/images/I/31DKMfOhB4L.jpg
# What is the item voltage? Mention the unit too
# 12v
# 379: https://m.media-amazon.com/images/I/31DOXzkNKSL.jpg
# What is the item depth? Mention the unit too
# 2.4 in / 6.1 cm
# 380: https://m.media-amazon.com/images/I/31DOXzkNKSL.jpg
# What is the item height? Mention the unit too
# 2.4 in / 6.1 cm
# 381: https://m.media-amazon.com/images/I/31DOXzkNKSL.jpg
# What is the item width? Mention the unit too
# 4.7 in / 12 cm
# 382: https://m.media-amazon.com/images/I/31DOqLer9YL.jpg
# What is the item height? Mention the unit too
# 60 cm
# 3.9 cm
# 383: https://m.media-amazon.com/images/I/31DOvGqtL5L.jpg
# What is the item net weight? Mention the unit too
# 18 g
# 384: https://m.media-amazon.com/images/I/31DTUHgs+EL.jpg
# What is the item voltage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 385: https://m.media-amazon.com/images/I/31DTUHgs+EL.jpg
# What is the item wattage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 386: https://m.media-amazon.com/images/I/31DThunqDhL.jpg
# What is the item depth? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 387: https://m.media-amazon.com/images/I/31DThunqDhL.jpg
# What is the item width? Mention the unit too
# 14cm(5.5in)
# 388: https://m.media-amazon.com/images/I/31Dbs085g7L.jpg
# What is the item voltage? Mention the unit too
# 3.6v
# 389: https://m.media-amazon.com/images/I/31Dcdu1QcDL.jpg
# What is the item height? Mention the unit too
# 31.4
# 390: https://m.media-amazon.com/images/I/31DmuoP26RL.jpg
# What is the item item_volume? Mention the unit too
# 12 fl oz
# 391: https://m.media-amazon.com/images/I/31DmuvUrq-L.jpg
# What is the item width? Mention the unit too
# 40 cm
# 40 cm
# 100 cm
# 392: https://m.media-amazon.com/images/I/31DmuvUrq-L.jpg
# What is the item height? Mention the unit too
# 40 cm 100 cm
# 393: https://m.media-amazon.com/images/I/31DvN4cwQUL.jpg
# What is the item depth? Mention the unit too
# 4.5
# 394: https://m.media-amazon.com/images/I/31DvN4cwQUL.jpg
# What is the item width? Mention the unit too
# 4.5
# 395: https://m.media-amazon.com/images/I/31DvN4cwQUL.jpg
# What is the item height? Mention the unit too
# 11.5cm/4.5inch
# 396: https://m.media-amazon.com/images/I/31DwFD7WLrL.jpg
# What is the item net weight? Mention the unit too
# ...
# 280ml
# 4079: https://m.media-amazon.com/images/I/418H3JFJkiL.jpg
# What is the item net weight? Mention the unit too
# 12 oz
# 4080: https://m.media-amazon.com/images/I/418H7BW0hRL.jpg
# What is the item net weight? Mention the unit too
# 287 lbs
# 4081: https://m.media-amazon.com/images/I/418HUBljDuL.jpg
# What is the item voltage? Mention the unit too
# 220v 50hz
# 4082: https://m.media-amazon.com/images/I/418HUBljDuL.jpg
# What is the item wattage? Mention the unit too
# 250
# 4083: https://m.media-amazon.com/images/I/418INeKfiOS.jpg
# What is the item width? Mention the unit too
# 115.5 mm
# 4084: https://m.media-amazon.com/images/I/418IlP-8q5L.jpg
# What is the item voltage? Mention the unit too
# 110
# 4085: https://m.media-amazon.com/images/I/418Iz6Z0HCL.jpg
# What is the item height? Mention the unit too
# 3.75 in 9.5 cm
# 4086: https://m.media-amazon.com/images/I/418Iz6Z0HCL.jpg
# What is the item depth? Mention the unit too
# 3.75 in 9.5 cm
# 4087: https://m.media-amazon.com/images/I/418J2N+a5rS.jpg
# What is the item width? Mention the unit too
# 201 cm
# 4088: https://m.media-amazon.com/images/I/418J2N+a5rS.jpg
# What is the item height? Mention the unit too
# 24.5 cm
# 4089: https://m.media-amazon.com/images/I/418JGLzOsGL.jpg
# What is the item height? Mention the unit too
# 28"
# 4090: https://m.media-amazon.com/images/I/418JcJ0l7JL.jpg
# What is the item item_volume? Mention the unit too
# 1.76 fl oz
# 4091: https://m.media-amazon.com/images/I/418JxeCs19L.jpg
# What is the item net weight? Mention the unit too
# 1 lb
# 4092: https://m.media-amazon.com/images/I/418K0+Fi22L.jpg
# What is the item depth? Mention the unit too
# 1.5 cm
# 4093: https://m.media-amazon.com/images/I/418KMAHWlkL.jpg
# What is the item depth? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 4094: https://m.media-amazon.com/images/I/418KMAHWlkL.jpg
# What is the item width? Mention the unit too
# 30cm/11.8in
# 4095: https://m.media-amazon.com/images/I/418Km6h5CQL.jpg
# What is the item height? Mention the unit too
# 30 cm
# 4096: https://m.media-amazon.com/images/I/418LSjqsOnL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 4097: https://m.media-amazon.com/images/I/418LVk-bh+L.jpg
# What is the item net weight? Mention the unit too
# 200g
# 4098: https://m.media-amazon.com/images/I/418LfA2k9hS.jpg
# What is the item depth? Mention the unit too
# 7.87 in / 20 cm
# 4099: https://m.media-amazon.com/images/I/418LfA2k9hS.jpg
# What is the item height? Mention the unit too
# 5.1 in / 13 cm
# 4100: https://m.media-amazon.com/images/I/418MHPuNDUL.jpg
# What is the item depth? Mention the unit too
# 11 inch
# 4101: https://m.media-amazon.com/images/I/418MHPuNDUL.jpg
# What is the item width? Mention the unit too
# 11 inch
# 4102: https://m.media-amazon.com/images/I/418Mm8vVZKS.jpg
# What is the item height? Mention the unit too
# 5.5cm (2.2inch)
# 4103: https://m.media-amazon.com/images/I/418Nf8zfcLL.jpg
# What is the item height? Mention the unit too
# 3.93in/10cm
# 4104: https://m.media-amazon.com/images/I/418Nf8zfcLL.jpg
# What is the item depth? Mention the unit too
# 3.93in
# 4105: https://m.media-amazon.com/images/I/418NkYyF2yL.jpg
# What is the item net weight? Mention the unit too
# 0.15lb
# 4106: https://m.media-amazon.com/images/I/418O9iiswrL.jpg
# What is the item net weight? Mention the unit too
# 0.6g
# 4107: https://m.media-amazon.com/images/I/418OYaUPF9L.jpg
# What is the item voltage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 4108: https://m.media-amazon.com/images/I/418Oc8eqgvL.jpg
# What is the item width? Mention the unit too
# 1.50"
# 4109: https://m.media-amazon.com/images/I/418Oc8eqgvL.jpg
# What is the item depth? Mention the unit too
# 1.50"
# 4110: https://m.media-amazon.com/images/I/418Oc8eqgvL.jpg
# What is the item height? Mention the unit too
# 1.50"
# 4111: https://m.media-amazon.com/images/I/418OdZk6zZS.jpg
# What is the item voltage? Mention the unit too
# 110v
# 4112: https://m.media-amazon.com/images/I/418OiMQO0jL.jpg
# What is the item width? Mention the unit too
# 2.75 in
# 4113: https://m.media-amazon.com/images/I/418OiMQO0jL.jpg
# What is the item height? Mention the unit too
# 2.75 in
# 4114: https://m.media-amazon.com/images/I/418OiMQO0jL.jpg
# What is the item depth? Mention the unit too
# 1.75 in
# 4115: https://m.media-amazon.com/images/I/418Ol9vRHtL.jpg
# What is the item voltage? Mention the unit too
# 120v
# 4116: https://m.media-amazon.com/images/I/418OmCAsl2L.jpg
# What is the item voltage? Mention the unit too
# 120v/60hz
# 4117: https://m.media-amazon.com/images/I/418PJ5ZzhvL.jpg
# What is the item net weight? Mention the unit too
# 158g
# 4118: https://m.media-amazon.com/images/I/418PcJ6CzdL.jpg
# What is the item voltage? Mention the unit too
# 5v/2.0a
# 4119: https://m.media-amazon.com/images/I/418PmWkSQML.jpg
# What is the item item_volume? Mention the unit too
# 30ml
# 4120: https://m.media-amazon.com/images/I/418QB0FYzWL.jpg
# What is the item width? Mention the unit too
# 0.375"
# 4121: https://m.media-amazon.com/images/I/418QB0FYzWL.jpg
# What is the item height? Mention the unit too
# 0.375"
# 4122: https://m.media-amazon.com/images/I/418QOz3xUtL.jpg
# What is the item depth? Mention the unit too
# 3.94
# 4123: https://m.media-amazon.com/images/I/418RJEop1OL.jpg
# What is the item height? Mention the unit too
# 2.4 in /6.1 cm
# 4124: https://m.media-amazon.com/images/I/418RJEop1OL.jpg
# What is the item depth? Mention the unit too
# 2.4 in /6.1 cm
# 4125: https://m.media-amazon.com/images/I/418RnIlhlWL.jpg
# What is the item width? Mention the unit too
# 5.91 in.
# 4126: https://m.media-amazon.com/images/I/418RnIlhlWL.jpg
# What is the item depth? Mention the unit too
# 5.91 in.
# 4127: https://m.media-amazon.com/images/I/418SdpinZCL.jpg
# What is the item net weight? Mention the unit too
# 12 oz
# 4128: https://m.media-amazon.com/images/I/418T+I7J6BL.jpg
# What is the item depth? Mention the unit too
# 150
# 4129: https://m.media-amazon.com/images/I/418TAZKn9CL.jpg
# What is the item net weight? Mention the unit too
# 1100 - 1150
# 4130: https://m.media-amazon.com/images/I/418TEibq+KL.jpg
# What is the item voltage? Mention the unit too
# 24v
# 4131: https://m.media-amazon.com/images/I/418TEibq+KL.jpg
# What is the item wattage? Mention the unit too
# 1200
# 4132: https://m.media-amazon.com/images/I/418UYUrclBL.jpg
# What is the item height? Mention the unit too
# 40 cm
# 100 cm
# 53 cm
# 4133: https://m.media-amazon.com/images/I/418V6krSE5L.jpg
# What is the item wattage? Mention the unit too
# 1200w
# 4134: https://m.media-amazon.com/images/I/418V6krSE5L.jpg
# What is the item net weight? Mention the unit too
# 2.26002
# 4135: https://m.media-amazon.com/images/I/418VyX3l07L.jpg
# What is the item wattage? Mention the unit too
# 6.5
# 4136: https://m.media-amazon.com/images/I/418VyX3l07L.jpg
# What is the item voltage? Mention the unit too
# 120v
# 4137: https://m.media-amazon.com/images/I/418WABSJoXS.jpg
# What is the item width? Mention the unit too
# 31.5cm
# 4138: https://m.media-amazon.com/images/I/418WhMzKGQL.jpg
# What is the item net weight? Mention the unit too
# 16.4 oz
# 4139: https://m.media-amazon.com/images/I/418WzdTLwpL.jpg
# What is the item net weight? Mention the unit too
# 68lbs
# 4140: https://m.media-amazon.com/images/I/418Xub+WrRL.jpg
# What is the item wattage? Mention the unit too
# 500w
# 4141: https://m.media-amazon.com/images/I/418YczyHIBL.jpg
# What is the item net weight? Mention the unit too
# 13.2 oz
# 4142: https://m.media-amazon.com/images/I/418Yw-tfB3L.jpg
# What is the item net weight? Mention the unit too
# 1.4 kg
# 4143: https://m.media-amazon.com/images/I/418ZAhnKVYL.jpg
# What is the item wattage? Mention the unit too
# 750w
# 4144: https://m.media-amazon.com/images/I/418ZYGx8O1L.jpg
# What is the item width? Mention the unit too
# 2cm/0.8in
# 4145: https://m.media-amazon.com/images/I/418ZYGx8O1L.jpg
# What is the item depth? Mention the unit too
# 2cm/0.8in
# 4146: https://m.media-amazon.com/images/I/418ZwDn2VCL.jpg
# What is the item height? Mention the unit too
# 10cm
# 4147: https://m.media-amazon.com/images/I/418ZwDn2VCL.jpg
# What is the item width? Mention the unit too
# 4.7cm
# 4148: https://m.media-amazon.com/images/I/418ZwDn2VCL.jpg
# What is the item depth? Mention the unit too
# 10cm
# 4149: https://m.media-amazon.com/images/I/418aLQiWppL.jpg
# What is the item net weight? Mention the unit too
# 8oz
# 4150: https://m.media-amazon.com/images/I/418aVDwnq+S.jpg
# What is the item voltage? Mention the unit too
# 3.7V
# 4151: https://m.media-amazon.com/images/I/418ah1Ws61L.jpg
# What is the item height? Mention the unit too
# 170 mm height
# 4152: https://m.media-amazon.com/images/I/418ah1Ws61L.jpg
# What is the item depth? Mention the unit too
# 150 mm diameter 170 mm height
# 4153: https://m.media-amazon.com/images/I/418b2mJJZyL.jpg
# What is the item item_volume? Mention the unit too
# 12oz
# 4154: https://m.media-amazon.com/images/I/418bNXPdckS.jpg
# What is the item voltage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 4155: https://m.media-amazon.com/images/I/418bunTMO-L.jpg
# What is the item width? Mention the unit too
# 90cm
# 4156: https://m.media-amazon.com/images/I/418bunTMO-L.jpg
# What is the item depth? Mention the unit too
# 90cm
# 4157: https://m.media-amazon.com/images/I/418bunTMO-L.jpg
# What is the item height? Mention the unit too
# 90cm
# 4158: https://m.media-amazon.com/images/I/418bw9HKCQL.jpg
# What is the item height? Mention the unit too
# 38 cm
# 40 cm
# 160 cm
# 4159: https://m.media-amazon.com/images/I/418cQo9zh1L.jpg
# What is the item height? Mention the unit too
# 120cm
# 4160: https://m.media-amazon.com/images/I/418cbFto-GL.jpg
# What is the item net weight? Mention the unit too
# 330lbs
# 4161: https://m.media-amazon.com/images/I/418d3w+7EtS.jpg
# What is the item net weight? Mention the unit too
# 330lbs
# 4162: https://m.media-amazon.com/images/I/418d8PaHtLS.jpg
# What is the item depth? Mention the unit too
# 20cm
# 4163: https://m.media-amazon.com/images/I/418d8PaHtLS.jpg
# What is the item width? Mention the unit too
# 15cm
# 4164: https://m.media-amazon.com/images/I/418d8PaHtLS.jpg
# What is the item height? Mention the unit too
# 20cm
# 4165: https://m.media-amazon.com/images/I/418dLe5At+L.jpg
# What is the item depth? Mention the unit too
# 13 cm
# 4166: https://m.media-amazon.com/images/I/418dLe5At+L.jpg
# What is the item height? Mention the unit too
# 15 cm
# 4167: https://m.media-amazon.com/images/I/418dTkS-UZL.jpg
# What is the item width? Mention the unit too
# 14 inch
# 4168: https://m.media-amazon.com/images/I/418dTkS-UZL.jpg
# What is the item depth? Mention the unit too
# 10 inch, 14 inch
# 4169: https://m.media-amazon.com/images/I/418dXyLZLtL.jpg
# What is the item net weight? Mention the unit too
# 800lbs
# 4170: https://m.media-amazon.com/images/I/418dmqus4RL.jpg
# What is the item width? Mention the unit too
# 9.9 in / 25 cm
# 4171: https://m.media-amazon.com/images/I/418dmqus4RL.jpg
# What is the item depth? Mention the unit too
# 1.5
# 4172: https://m.media-amazon.com/images/I/418du9yUHoL.jpg
# What is the item height? Mention the unit too
# 16.7 in / 42.5 cm
# 4173: https://m.media-amazon.com/images/I/418du9yUHoL.jpg
# What is the item depth? Mention the unit too
# 7.4 in / 19 cm
# 4174: https://m.media-amazon.com/images/I/418eZMJgfhL.jpg
# What is the item height? Mention the unit too
# 195mm
# 4175: https://m.media-amazon.com/images/I/418eZMJgfhL.jpg
# What is the item depth? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 4176: https://m.media-amazon.com/images/I/418esyAXQPL.jpg
# What is the item width? Mention the unit too
# 122.00
# 4177: https://m.media-amazon.com/images/I/418f6J-2mRL.jpg
# What is the item width? Mention the unit too
# 699 cm
# 4178: https://m.media-amazon.com/images/I/418fkQoGYjL.jpg
# What is the item width? Mention the unit too
# 1.26in
# 4179: https://m.media-amazon.com/images/I/418fw59coqL.jpg
# What is the item depth? Mention the unit too
# 5
# 4180: https://m.media-amazon.com/images/I/418fzIOiUdL.jpg
# What is the item depth? Mention the unit too
# 5.3in/13.5cm
# 4181: https://m.media-amazon.com/images/I/418gGL0VGDL.jpg
# What is the item depth? Mention the unit too
# 5
# 4182: https://m.media-amazon.com/images/I/418gXhvJ4jL.jpg
# What is the item net weight? Mention the unit too
# 16 oz
# 4183: https://m.media-amazon.com/images/I/418gcmFp4hL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 4184: https://m.media-amazon.com/images/I/418gqdI4IiL.jpg
# What is the item depth? Mention the unit too
# 1.55in
# 4185: https://m.media-amazon.com/images/I/418hPW2K44L.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 4186: https://m.media-amazon.com/images/I/418huPBOTJS.jpg
# What is the item voltage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 4187: https://m.media-amazon.com/images/I/418hyEOTFBL.jpg
# What is the item net weight? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 4188: https://m.media-amazon.com/images/I/418iEMfxz2L.jpg
# What is the item width? Mention the unit too
# 5.89
# 4189: https://m.media-amazon.com/images/I/418iXGzfgHS.jpg
# What is the item depth? Mention the unit too
# 5.31 in / 13.5 cm
# 4190: https://m.media-amazon.com/images/I/418iXGzfgHS.jpg
# What is the item height? Mention the unit too
# 7.07 in / 18 cm
# 4191: https://m.media-amazon.com/images/I/418ivk5iuQL.jpg
# What is the item net weight? Mention the unit too
# 10 oz
# 4192: https://m.media-amazon.com/images/I/418jA4AaweL.jpg
# What is the item wattage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 4193: https://m.media-amazon.com/images/I/418jAxHiB7L.jpg
# What is the item wattage? Mention the unit too
# 700w
# 4194: https://m.media-amazon.com/images/I/418jQb1-VIL.jpg
# What is the item depth? Mention the unit too
# 10.5 cm
# 4195: https://m.media-amazon.com/images/I/418jQb1-VIL.jpg
# What is the item height? Mention the unit too
# 16.5 cm
# 4196: https://m.media-amazon.com/images/I/418jltqNI2L.jpg
# What is the item height? Mention the unit too
# 16.54 in
# 4197: https://m.media-amazon.com/images/I/418k3PqhDrL.jpg
# What is the item depth? Mention the unit too
# 5mm
# 4198: https://m.media-amazon.com/images/I/418k8hUkx+L.jpg
# What is the item net weight? Mention the unit too
# 1.62 oz
# 4199: https://m.media-amazon.com/images/I/418kE4nqD1L.jpg
# What is the item voltage? Mention the unit too
# Sorry, as a base VLM I am not trained to answer this question.
# 4200: https://m.media-amazon.com/images/I/418kEYVQ2pL.jpg
# What is the item net weight? Mention the unit too
# 18.5 lbs
# 4201: https://m.media-amazon.com/images/I/418kZaEAZTL.jpg
# What is the item voltage? Mention the unit too
# 220v 50hz
# 4202: https://m.media-amazon.com/images/I/418kZaEAZTL.jpg
# What is the item wattage? Mention the unit too
# 1000w
# 4203: https://m.media-amazon.com/images/I/418kfFP1MfL.jpg
# What is the item height? Mention the unit too
# 36.13
# 4204: https://m.media-amazon.com/images/I/418lXXhl3RL.jpg
# What is the item width? Mention the unit too
# 9.1 inch
# 4205: https://m.media-amazon.com/images/I/418lcRxT9HL.jpg
# What is the item height? Mention the unit too
# 26mm
# 4206: https://m.media-amazon.com/images/I/418ll39ZBqL.jpg
# What is the item height? Mention the unit too
# 3.5cm
# 4207: https://m.media-amazon.com/images/I/418mNPigjbL.jpg
# What is the item wattage? Mention the unit too
# 80
# 4208: https://m.media-amazon.com/images/I/418mNPigjbL.jpg
# What is the item voltage? Mention the unit too
# 12v
# 4209: https://m.media-amazon.com/images/I/418mWnPdGUL.jpg
# What is the item depth? Mention the unit too
# 2 in
# 4210: https://m.media-amazon.com/images/I/418mWnPdGUL.jpg
# What is the item height? Mention the unit too
# 6.25 in
# 4211: https://m.media-amazon.com/images/I/418mbRdslgL.jpg
# What is the item depth? Mention the unit too
# 12mm
# 4212: https://m.media-amazon.com/images/I/418mbRdslgL.jpg
# What is the item width? Mention the unit too
# 12mm
# 4213: https://m.media-amazon.com/images/I/418mbRdslgL.jpg
# What is the item height? Mention the unit too
# 65mm 12mm
# 4214: https://m.media-amazon.com/images/I/418miP31CxL.jpg
# What is the item net weight? Mention the unit too
# 18kg
# 4215: https://m.media-amazon.com/images/I/418n8nmU0iS.jpg

# %%
result.to_csv("result.csv")
